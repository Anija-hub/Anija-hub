# %% [markdown]
# <a href="https://colab.research.google.com/github/Anija-hub/Anija-hub/blob/master/vaccinated_Statewise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4dda7306-e347-4eff-a1d7-412daffe8bed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dda7306-e347-4eff-a1d7-412daffe8bed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vaccine_doses_statewise.csv to vaccine_doses_statewise (2).csv
# Saving cowin_vaccine_data_statewise.csv to cowin_vaccine_data_statewise (2).csv
# Saving india_state_wise_projected_population_2021.csv to india_state_wise_projected_population_2021 (2).csv
# Saving covid_vaccine_data_districtwise.csv to covid_vaccine_data_districtwise (2).csv

# %%
df=pd.read_csv("vaccine_doses_statewise.csv")

# %%
df
# Out:
#                                        State  ...  10/07/2021
# 0                Andaman and Nicobar Islands  ...      222640
# 1                             Andhra Pradesh  ...    16945991
# 2                          Arunachal Pradesh  ...      701700
# 3                                      Assam  ...     7911460
# 4                                      Bihar  ...    18556378
# 5                                 Chandigarh  ...      605255
# 6                               Chhattisgarh  ...    10364377
# 7   Dadra and Nagar Haveli and Daman and Diu  ...      526086
# 8                                      Delhi  ...     8890766
# 9                                        Goa  ...     1083528
# 10                                   Gujarat  ...    27637323
# 11                                   Haryana  ...     9848296
# 12                          Himachal Pradesh  ...     4281031
# 13                         Jammu and Kashmir  ...     5115398
# 14                                 Jharkhand  ...     7649924
# 15                                 Karnataka  ...    25519101
# 16                                    Kerala  ...    15667263
# 17                                    Ladakh  ...      242115
# 18                               Lakshadweep  ...       58606
# 19                            Madhya Pradesh  ...    23920067
# 20                               Maharashtra  ...    36344581
# 21                                   Manipur  ...      861178
# 22                                 Meghalaya  ...      810002
# 23                                   Mizoram  ...      671369
# 24                                  Nagaland  ...      589915
# 25                                    Odisha  ...    13443965
# 26                                Puducherry  ...      586989
# 27                                    Punjab  ...     8184234
# 28                                 Rajasthan  ...    26331461
# 29                                    Sikkim  ...      560587
# 30                                Tamil Nadu  ...    17405050
# 31                                 Telangana  ...    12395197
# 32                                   Tripura  ...     2705506
# 33                             Uttar Pradesh  ...    37166392
# 34                               Uttarakhand  ...     4889353
# 35                               West Bengal  ...    24068320
# 36                             Miscellaneous  ...     3271182
# 37                                     Total  ...   376032586
#
# [38 rows x 176 columns]

# %%
import matplotlib.pyplot as plt

# %%
df=df.rename(columns={'03/07/2021':'Total vaccinated'})

# %%
df=df.drop(36,axis=0)

# %%
#population of each state
Population=[420000,54400000,1592000,36000000,127000000,1169000,29800000,620000,19000000,1600000,64300000,28500000,7500000,13800000,39200000,68300000,36000000,290000,74151,87000000,124300000,3200000,3400000,1255000,2300000,46900000,1432000,30000000,82500000,700000,78500000,39800000,4200000,240000000,11400000,100000000,1386452151]

# %%
df['Total Population']=Population

# %%
df['%age Vaccinated']=(df['Total vaccinated'] / df['Total Population']) * 100

# %%
Vaccination=df[['State','%age Vaccinated']].drop(37)

# %%
Total=df[['State','%age Vaccinated']]
Total=Total.loc[Total.State=='Total']

# %%
plt.figure(figsize=(15,8))
plt.bar(Vaccination['State'],Vaccination['%age Vaccinated'],color=(Vaccination.State=='Telangana').map({True:'#8C000F',False:'#929591'}))
plt.axhline(Total['%age Vaccinated'].values, color = '#008000', ls = '--', lw = 5,label ='Total %age vaccinated in India')
plt.xlabel('States')
plt.ylabel('Percentage')
plt.title('%age of people vaccinated in each state')
plt.xticks(rotation=90)
plt.show()
